# %% [markdown]
# <a href="https://colab.research.google.com/github/alicamoglu/team1_data_Preprocessing/blob/main/first13column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re

df2=pd.read_csv(r"/content/drive/MyDrive/data.csv")

# %%
df2
# Out:
#        Unnamed: 0                 location          make      model  \
# 0               0         LOON OP ZAND, NL   \n,Audi ,\n   \n,A3,\n
# 1               1              HEERLEN, NL   \n,Audi ,\n   \n,A3,\n
# 2               3        BAARLE-NASSAU, NL   \n,Audi ,\n   \n,A1,\n
# 3               4              ZUTPHEN, NL   \n,Audi ,\n   \n,A1,\n
# 4               7          HAAKSBERGEN, NL   \n,Audi ,\n   \n,A3,\n
# ...           ...                      ...           ...        ...
# 62761       71098           Etten-Leur, NL  \n,Volvo ,\n  \n,S60,\n
# 62762       71099  HENDRIK-IDO-AMBACHT, NL  \n,Volvo ,\n  \n,S60,\n
# 62763       71101             LELYSTAD, NL  \n,Volvo ,\n  \n,S60,\n
# 62764       71102            Amsterdam, NL  \n,Volvo ,\n  \n,S40,\n
# 62765       71103          SOESTERBERG, NL  \n,Volvo ,\n  \n,S60,\n
#
#                                        short_description  \
# 0                              2.0 FSI Ambition Pro Line
# ...

# %%
df3=df2.copy()

# %%
df3.shape
# Out:
# (62766, 49)

# %%
df3.head(15)
# Out:
#     Unnamed: 0                    location         make     model  \
# 0            0            LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1            1                 HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2            3           BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3            4                 ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4            7             HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
# 5            8                   WEZEP, NL  \n,Audi ,\n  \n,A3,\n
# 6            9                 UTRECHT, NL  \n,Audi ,\n  \n,A1,\n
# 7           10                  HEESCH, NL  \n,Audi ,\n  \n,A3,\n
# 8           11  VALKENBURG AAN DE GEUL, NL  \n,Audi ,\n  \n,A1,\n
# 9           12             NIJKERK GLD, NL  \n,Audi ,\n  \n,A3,\n
# 10          13               GRONINGEN, NL  \n,Audi ,\n  \n,A3,\n
# 11          16               ROTTERDAM, NL  \n,Audi ,\n  \n,A1,\n
# 12          17                    GOES, NL  \n,Audi ,\n  \n,A5,\n
# ...

# %%
df = df3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62766 entries, 0 to 62765
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               62766 non-null  int64
#  1   location                 62766 non-null  object
#  2   make                     62766 non-null  object
#  3   model                    62766 non-null  object
#  4   short_description        62617 non-null  object
#  5   price                    62766 non-null  object
#  6   mileage                  62766 non-null  object
#  7   gearbox                  62766 non-null  object
#  8   registration             62729 non-null  object
#  9   fuel_type                62766 non-null  object
#  10  power                    62766 non-null  object
#  11  seller                   62766 non-null  object
#  12  body_type                62766 non-null  object
#  13  type                     62766 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  62766.000000
# mean   35563.827709
# std    20562.958458
# min        0.000000
# 25%    17718.250000
# 50%    35595.500000
# 75%    53391.750000
# max    71103.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'location', 'make', 'model', 'short_description', 'price',
#        'mileage', 'gearbox', 'registration', 'fuel_type', 'power', 'seller',
#        'body_type', 'type', 'drivetrain', 'seats', 'doors', 'country_version',
#        'offer_number', 'warranty', 'Mileage', 'first_registration',
#        'production_date', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'previous_owner',
#        'last_timing_belt_change', 'Power', 'Gearbox', 'engine_size', 'gears',
#        'cylinders', 'empty_weight', 'Fuel_type', 'fuel_consumption',
#        'co2_emissions', 'emission_class', 'emissions_sticker',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n',
#        '\nSafety & Security\n', 'extras', '\ncolour', '\nmanufacturer_color',
#        '\npaint', ' upholstery_colour ', ' upholstery '],
#       dtype='object')

# %%
df=df.drop(["Unnamed: 0"],axis=1) # column0 removed

# %%
df.describe()
# Out:
#              location        make     model short_description  \
# count           62766       62766     62766             62617
# unique           2344          20       754             54368
# top     ROTTERDAM, NL  \n,BMW ,\n  \n,A3,\n  1.4 TSI Highline
# freq             1379        6942      1171                58
#
#                      price          mileage          gearbox registration  \
# count                62766            62766            62766        62729
# unique                8179            45618               10          302
# top     [['\n', '', '\n']]  ['', ['10 km']]  \n,Automatic,\n      01/2021
# freq                  1378             1371            36633         2883
#
#              fuel_type       power                seller  \
# count            62766       62766                 62766
# unique              12         361                     5
# top     \n,Gasoline,\n  [None, '']  ['\n', ['Dealer\n']]
# ...

# %%
df.describe().T
# Out:
#                            count unique  \
# location                   62766   2344
# make                       62766     20
# model                      62766    754
# short_description          62617  54368
# price                      62766   8179
# mileage                    62766  45618
# gearbox                    62766     10
# registration               62729    302
# fuel_type                  62766     12
# power                      62766    361
# seller                     62766      5
# body_type                  62766     13
# type                       62766      5
# drivetrain                 62766      4
# seats                      62766     11
# doors                      62766      7
# country_version            62766     27
# offer_number               62766  50143
# warranty                   62766     17
# Mileage                    62766      2
# first_registration         62766    298
# production_date            62766     26
# ...

# %%
df.head()
# Out:
#             location         make     model  \
# 0   LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# ...

# %%
df.dtypes
# Out:
# location                     object
# make                         object
# model                        object
# short_description            object
# price                        object
# mileage                      object
# gearbox                      object
# registration                 object
# fuel_type                    object
# power                        object
# seller                       object
# body_type                    object
# type                         object
# drivetrain                   object
# seats                        object
# doors                        object
# country_version              object
# offer_number                 object
# warranty                     object
# Mileage                      object
# first_registration           object
# production_date              object
# general_inspection           object
# last_service                 object
# full_service_history         object
# non_smoker_vehicle           object
# ...

# %%
#df13 = df.iloc[0:13]

# %%
df13=df.T.iloc[0:13]

# %%
df13.shape
# Out:
# (13, 62766)

# %%
df13.head()

# %%
df13=df13.T

# %%
df13.head()

# %%
df13.shape

# %%
df14 = df3.iloc[:, 1:14]

# %%
df14.shape

# %%
df14.head()

# %%
df14["make"].head()

# %%
df14["make"]=df14["make"].replace("\n,","",regex=True)

# %%
df14.head()

# %%
df14["make"].value_counts()   # which value , how many times exist

# %%
df14["gearbox"].value_counts()   # which value , how many times exist

# %%
#df14["make"].str.split(",").str[1]
df14["make"]=df14["make"].str.split(",").str[0]
df14["make"].head()

# %%
df14['make'].unique()

# %%
df14["make"].value_counts()   # which value , how many times exist

# %%
#df14["make"]=df14["make"].replace("\n,","",regex=True)
df14["gearbox"]=df14["gearbox"].str.split(",").str[1]
df14["gearbox"].head()

# %%
df14["gearbox"].value_counts()   # which value , how many times exist

# %%
df14["model"].value_counts()   # which value , how many times exist

# %%
df14['model'].unique()

# %%
df14["model"]=df14["model"].str.split(",").str[1]
df14["model"].head()

# %%
df14["fuel_type"].value_counts()   # which value , how many times exist

# %%
df14["fuel_type"]=df14["fuel_type"].str.split(",").str[1]
df14["fuel_type"].head()

# %%
df14['power'].value_counts()

# %%
u = df14['power'].unique()
for i in u:
  print(i)

# %%
df14['body_type'].value_counts()

# %%
df14["body_type"]=df14["body_type"].str.split(",").str[1]
df14["body_type"].head()

# %%
df14['type'].value_counts()

# %%
df14["type"]=df14["type"].str.split(",").str[1]
df14["type"].head()

# %%
df14.head()

# %%
df15 = df3.iloc[:, 1:14]

# %%
df15.head()

# %%
df15['type'].value_counts()

# %%
type(df14['make'])

# %%
df14['make'].describe()

# %%
df14['model'].describe()

# %%
df14['make'].unique()             # ?

# %%
df14["make"].isnull().sum()

# %%
#df.set_option('display.max_colwidth', None) 
pd.set_option('display.max_columns', None)

# %%
df

# %%
df

# %%
df14['price'] = df14['price'].str.replace(r"\[\['\\n', '", "", regex=True)

# %%
df14['price'] = df14['price'].str.replace(r"', '\\n'\]\]", "", regex=True)

# %%
df14['mileage'] = df14['mileage'].str.replace(r"\['', \[\'| km\'\]\]", "", regex=True)

# %%
df14['seller'] = df14['seller'].str.replace(r"\['\\n', \['", "", regex=True)

# %%
df14['seller'] = df14['seller'].str.replace(r"\\n'\]\]", "", regex=True)

# %%
df14

# %%
df14['make'].unique()

# %%
df_type=df14['make'].copy()                                                           #önce type sutununun  kopyasini alalim
type_dummies = df_type.str.get_dummies()                                             #icindeki uniq degerlere gore sutunlara ayiracak,str old icin
type_dummies.columns = ['Audi ', 'BMW ', 'Ford ', 'Mercedes-Benz ', 'Opel ', 'Volkswagen ',
       'Renault ', 'Citroen ', 'Chevrolet ', 'Dacia ', 'Fiat ', 'Honda ',
       'Hyundai ', 'Kia ', 'Mazda ', 'Peugeot ', 'Skoda ', 'Toyota ',
       'Tesla ', 'Volvo ']   #yeni sutunlarin adlarini duzenleme
df_type=type_dummies                                                                 #yeni halini kopya sutunumuzla degistirebiliriz artik
df_type.columns                                                                      #tekrar bi kontrol etmek icin
df_type.info()                                                                       #incelemek icin
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62766 entries, 0 to 62765
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Audi            62766 non-null  int64
#  1   BMW             62766 non-null  int64
#  2   Ford            62766 non-null  int64
#  3   Mercedes-Benz   62766 non-null  int64
#  4   Opel            62766 non-null  int64
#  5   Volkswagen      62766 non-null  int64
#  6   Renault         62766 non-null  int64
#  7   Citroen         62766 non-null  int64
#  8   Chevrolet       62766 non-null  int64
#  9   Dacia           62766 non-null  int64
#  10  Fiat            62766 non-null  int64
#  11  Honda           62766 non-null  int64
#  12  Hyundai         62766 non-null  int64
#  13  Kia             62766 non-null  int64
#  14  Mazda           62766 non-null  int64
#  15  Peugeot         62766 non-null  int64
#  16  Skoda           62766 non-null  int64
# ...

# %%
df14
# Out:
#                       location    make model  \
# 0             LOON OP ZAND, NL   Audi     A3
# 1                  HEERLEN, NL   Audi     A3
# 2            BAARLE-NASSAU, NL   Audi     A1
# 3                  ZUTPHEN, NL   Audi     A1
# 4              HAAKSBERGEN, NL   Audi     A3
# ...                        ...     ...   ...
# 62761           Etten-Leur, NL  Volvo    S60
# 62762  HENDRIK-IDO-AMBACHT, NL  Volvo    S60
# 62763             LELYSTAD, NL  Volvo    S60
# 62764            Amsterdam, NL  Volvo    S40
# 62765          SOESTERBERG, NL  Volvo    S60
#
#                                        short_description       price  mileage  \
# 0                              2.0 FSI Ambition Pro Line   € 4,450.-  191,066
# 1      Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...  € 12,950.-   94,758
# 2        1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.  € 12,450.-  145,102
# 3      S-Line | Automaat | Navigatie | Cruise-/Climat...  € 14,945.-  119,666
# ...
