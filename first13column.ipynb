# %%
import numpy as np
import pandas as pd

df2=pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 df2=pd.read_csv(r"/content/drive/MyDrive/data.csv")
#
# File c:\Users\alica\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\alica\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\alica\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\alica\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\alica\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/data.csv'

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df3=df2.copy()

# %%
df3.shape
# Out:
# (62766, 49)

# %%
df3.head(15)
# Out:
#     Unnamed: 0                    location         make     model  \
# 0            0            LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1            1                 HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2            3           BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3            4                 ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4            7             HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
# 5            8                   WEZEP, NL  \n,Audi ,\n  \n,A3,\n
# 6            9                 UTRECHT, NL  \n,Audi ,\n  \n,A1,\n
# 7           10                  HEESCH, NL  \n,Audi ,\n  \n,A3,\n
# 8           11  VALKENBURG AAN DE GEUL, NL  \n,Audi ,\n  \n,A1,\n
# 9           12             NIJKERK GLD, NL  \n,Audi ,\n  \n,A3,\n
# 10          13               GRONINGEN, NL  \n,Audi ,\n  \n,A3,\n
# 11          16               ROTTERDAM, NL  \n,Audi ,\n  \n,A1,\n
# 12          17                    GOES, NL  \n,Audi ,\n  \n,A5,\n
# 13          18                   SOEST, NL  \n,Audi ,\n  \n,A1,\n
# 14          19                  MEPPEL, NL  \n,Audi ,\n  \n,A5,\n
#
#                                     short_description  \
# 0                           2.0 FSI Ambition Pro Line
# 1   Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2     1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3   S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4   Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
# 5                          Sportback 30 TFSI/Automaat
# 6   Sportback 1.4 TFSI Pro Line S | S Line Pack | ...
# 7          1.8 TFSI Ambition Pro Line S aut. S-tronic
# 8   1.4 TSI  S-Tronic Navigatie MF Stuurwiel LED V...
# 9   Sportback 1.2 TFSI Ambition Stoelverw.V+A Airc...
# 10  Sportback 1.4 TFSI 125 pk Ambiente Advance Aut...
# 11  Sportback 1.4 TFSI Ambition 122PK FR94460 | EI...
# 12  Sportback 1.8 TFSI Pro Line (NAVIGATIESYSTEEM,...
# 13  Sportback 1.0 TFSI Pro Line S-Tronic | Navigat...
# 14                                1.8 TFSI PRO LINE S
#
#                            price               mileage          gearbox  \
# 0    [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1   [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2   [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3   [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4   [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
# 5   [['\n', '€ 24,750.-', '\n']]   ['', ['47,536 km']]  \n,Automatic,\n
# 6   [['\n', '€ 15,945.-', '\n']]   ['', ['94,530 km']]  \n,Automatic,\n
# 7   [['\n', '€ 12,950.-', '\n']]  ['', ['139,703 km']]  \n,Automatic,\n
# 8   [['\n', '€ 13,950.-', '\n']]  ['', ['103,626 km']]  \n,Automatic,\n
# 9   [['\n', '€ 10,945.-', '\n']]  ['', ['100,558 km']]  \n,Automatic,\n
# 10  [['\n', '€ 12,950.-', '\n']]   ['', ['91,763 km']]  \n,Automatic,\n
# 11  [['\n', '€ 16,151.-', '\n']]   ['', ['39,915 km']]  \n,Automatic,\n
# 12  [['\n', '€ 15,945.-', '\n']]  ['', ['154,802 km']]  \n,Automatic,\n
# 13  [['\n', '€ 15,945.-', '\n']]   ['', ['35,618 km']]  \n,Automatic,\n
# 14  [['\n', '€ 16,250.-', '\n']]  ['', ['123,606 km']]  \n,Automatic,\n
#
#    registration       fuel_type  ... emissions_sticker  \
# 0       08/2003  \n,Gasoline,\n  ...        \n,None,\n
# 1       10/2013  \n,Gasoline,\n  ...        \n,None,\n
# 2       06/2015  \n,Gasoline,\n  ...        \n,None,\n
# 3       10/2015  \n,Gasoline,\n  ...        \n,None,\n
# 4       10/2017  \n,Gasoline,\n  ...        \n,None,\n
# 5       03/2019  \n,Gasoline,\n  ...        \n,None,\n
# 6       03/2014  \n,Gasoline,\n  ...        \n,None,\n
# 7       07/2011  \n,Gasoline,\n  ...        \n,None,\n
# 8       08/2012  \n,Gasoline,\n  ...        \n,None,\n
# 9       01/2011  \n,Gasoline,\n  ...        \n,None,\n
# 10      08/2012  \n,Gasoline,\n  ...        \n,None,\n
# 11      06/2014  \n,Gasoline,\n  ...        \n,None,\n
# 12      06/2012  \n,Gasoline,\n  ...        \n,None,\n
# 13      08/2015  \n,Gasoline,\n  ...        \n,None,\n
# 14      05/2012  \n,Gasoline,\n  ...        \n,None,\n
#
#                             \nComfort & Convenience\n  \
# 0   [['Air conditioning', 'Armrest', 'Automatic cl...
# 1   [['Air conditioning', 'Automatic climate contr...
# 2   [['Air conditioning', 'Armrest', 'Automatic cl...
# 3   [['Air conditioning', 'Armrest', 'Automatic cl...
# 4   [['Air conditioning', 'Armrest', 'Electrical s...
# 5   [['Air conditioning', 'Automatic climate contr...
# 6   [['Air conditioning', 'Armrest', 'Automatic cl...
# 7   [['Air conditioning', 'Armrest', 'Cruise contr...
# 8   [['Air conditioning', 'Armrest', 'Automatic cl...
# 9   [['Air conditioning', 'Cruise control', 'Elect...
# 10  [['Air conditioning', 'Armrest', 'Automatic cl...
# 11  [['Air conditioning', 'Automatic climate contr...
# 12  [['Air conditioning', 'Automatic climate contr...
# 13  [['Air conditioning', 'Armrest', 'Automatic cl...
# 14  [['Air conditioning', 'Armrest', 'Automatic cl...
#
#                             \nEntertainment & Media\n  \
# 0                            [['CD player', 'Radio']]
# 1                            [['CD player', 'Radio']]
# 2   [['Bluetooth', 'CD player', 'On-board computer...
# 3   [['CD player', 'MP3', 'On-board computer', 'Ra...
# 4       [['CD player', 'On-board computer', 'Radio']]
# 5       [['CD player', 'On-board computer', 'Radio']]
# 6   [['CD player', 'MP3', 'On-board computer', 'Ra...
# 7   [['Bluetooth', 'CD player', 'On-board computer']]
# 8   [['Bluetooth', 'CD player', 'On-board computer...
# 9                     [['CD player', 'MP3', 'Radio']]
# 10                   [['On-board computer', 'Radio']]
# 11  [['CD player', 'MP3', 'On-board computer', 'Ra...
# 12                   [['On-board computer', 'Radio']]
# 13                                        [['Radio']]
# 14                            [['On-board computer']]
#
#                                 \nSafety & Security\n  \
# 0   [['ABS', 'Alarm system', 'Central door lock', ...
# 1   [['Alarm system', 'Central door lock', 'Centra...
# 2   [['ABS', 'Central door lock with remote contro...
# 3   [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 4   [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 5   [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 6   [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 7   [['ABS', 'Alarm system', 'Central door lock wi...
# 8   [['ABS', 'Central door lock with remote contro...
# 9   [['ABS', 'Alarm system', 'Central door lock', ...
# 10  [['ABS', 'Adaptive headlights', 'Bi-Xenon head...
# 11  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 12  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 13  [['ABS', 'Alarm system', 'Central door lock', ...
# 14  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
#
#                                                extras    \ncolour  \
# 0                                  [['Alloy wheels']]   \n4, Grey
# 1                            [['Alloy wheels (16")']]  \n4, White
# 2                            [['Alloy wheels (15")']]   \n4, Grey
# 3   [['Alloy wheels (17")', 'Shift paddles', 'Spor...  \n4, Black
# 4   [['Alloy wheels (17")', 'Sport seats', 'Sport ...   \n4, Grey
# 5                            [['Alloy wheels (16")']]   \n4, Grey
# 6   [['Alloy wheels (17")', 'Sport seats', 'Sport ...  \n4, Black
# 7   [['Alloy wheels (18")', 'Automatically dimming...   \n4, Grey
# 8             [['Alloy wheels (17")', 'Sport seats']]  \n4, White
# 9        [['Alloy wheels (17")', 'Sport suspension']]  \n4, White
# 10                           [['Alloy wheels (16")']]  \n4, Black
# 11                           [['Alloy wheels (17")']]    \n4, Red
# 12  [['Alloy wheels (17")', 'Automatically dimming...  \n4, Black
# 13                           [['Alloy wheels (15")']]   \n4, Grey
# 14  [['Alloy wheels (19")', 'Sport seats', 'Sport ...   \n4, Grey
#
#    \nmanufacturer_color            \npaint   upholstery_colour   \
# 0                  None  \npaint, Metallic  \nupholstery, Black
# 1                  None               None  \nupholstery, Black
# 2                  None  \npaint, Metallic                 None
# 3                  None               None  \nupholstery, Black
# 4                  None  \npaint, Metallic  \nupholstery, Black
# 5                  None  \npaint, Metallic   \nupholstery, Grey
# 6                  None  \npaint, Metallic                 None
# 7                  None  \npaint, Metallic                 None
# 8                  None               None                 None
# 9                  None               None   \nupholstery, Grey
# 10                 None  \npaint, Metallic   \nupholstery, Grey
# 11                 None               None   \nupholstery, Grey
# 12                 None  \npaint, Metallic  \nupholstery, Black
# 13                 None  \npaint, Metallic  \nupholstery, Black
# 14                 None  \npaint, Metallic                 None
#
#           upholstery
# 0          \n8, Cloth
# 1          \n8, Cloth
# 2                None
# 3   \n8, Part leather
# 4          \n8, Cloth
# 5          \n8, Cloth
# 6   \n8, Part leather
# 7   \n8, Full leather
# 8                None
# 9          \n8, Cloth
# 10         \n8, Cloth
# 11         \n8, Cloth
# 12  \n8, Full leather
# 13         \n8, Cloth
# 14  \n8, Part leather
#
# [15 rows x 49 columns]

# %%
df = df3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62766 entries, 0 to 62765
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               62766 non-null  int64
#  1   location                 62766 non-null  object
#  2   make                     62766 non-null  object
#  3   model                    62766 non-null  object
#  4   short_description        62617 non-null  object
#  5   price                    62766 non-null  object
#  6   mileage                  62766 non-null  object
#  7   gearbox                  62766 non-null  object
#  8   registration             62729 non-null  object
#  9   fuel_type                62766 non-null  object
#  10  power                    62766 non-null  object
#  11  seller                   62766 non-null  object
#  12  body_type                62766 non-null  object
#  13  type                     62766 non-null  object
#  14  drivetrain               62766 non-null  object
#  15  seats                    62766 non-null  object
#  16  doors                    62766 non-null  object
#  17  country_version          62766 non-null  object
#  18  offer_number             62766 non-null  object
#  19  warranty                 62766 non-null  object
#  20  Mileage                  62766 non-null  object
#  21  first_registration       62766 non-null  object
#  22  production_date          62766 non-null  object
#  23  general_inspection       62766 non-null  object
#  24  last_service             62766 non-null  object
#  25  full_service_history     62766 non-null  object
#  26  non_smoker_vehicle       62766 non-null  object
#  27  previous_owner           62766 non-null  object
#  28  last_timing_belt_change  62766 non-null  object
#  29  Power                    62766 non-null  object
#  30  Gearbox                  62766 non-null  object
#  31  engine_size              62766 non-null  object
#  32  gears                    62766 non-null  object
#  33  cylinders                62766 non-null  object
#  34  empty_weight             62766 non-null  object
#  35  Fuel_type                62766 non-null  object
#  36  fuel_consumption         62766 non-null  object
#  37  co2_emissions            62766 non-null  object
#  38  emission_class           62766 non-null  object
#  39  emissions_sticker        62766 non-null  object
#  40
# Comfort & Convenience
#   62766 non-null  object
#  41
# Entertainment & Media
#   62766 non-null  object
#  42
# Safety & Security
#       62766 non-null  object
#  43  extras                   62766 non-null  object
#  44
# colour                  62766 non-null  object
#  45
# manufacturer_color      62766 non-null  object
#  46
# paint                   62766 non-null  object
#  47   upholstery_colour       62766 non-null  object
#  48   upholstery              62766 non-null  object
# dtypes: int64(1), object(48)
# memory usage: 23.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  62766.000000
# mean   35563.827709
# std    20562.958458
# min        0.000000
# 25%    17718.250000
# 50%    35595.500000
# 75%    53391.750000
# max    71103.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'location', 'make', 'model', 'short_description', 'price',
#        'mileage', 'gearbox', 'registration', 'fuel_type', 'power', 'seller',
#        'body_type', 'type', 'drivetrain', 'seats', 'doors', 'country_version',
#        'offer_number', 'warranty', 'Mileage', 'first_registration',
#        'production_date', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'previous_owner',
#        'last_timing_belt_change', 'Power', 'Gearbox', 'engine_size', 'gears',
#        'cylinders', 'empty_weight', 'Fuel_type', 'fuel_consumption',
#        'co2_emissions', 'emission_class', 'emissions_sticker',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n',
#        '\nSafety & Security\n', 'extras', '\ncolour', '\nmanufacturer_color',
#        '\npaint', ' upholstery_colour ', ' upholstery '],
#       dtype='object')

# %%
df=df.drop(["Unnamed: 0"],axis=1) # column0 removed

# %%
df.describe()
# Out:
#              location        make     model short_description  \
# count           62766       62766     62766             62617
# unique           2344          20       754             54368
# top     ROTTERDAM, NL  \n,BMW ,\n  \n,A3,\n  1.4 TSI Highline
# freq             1379        6942      1171                58
#
#                      price          mileage          gearbox registration  \
# count                62766            62766            62766        62729
# unique                8179            45618               10          302
# top     [['\n', '', '\n']]  ['', ['10 km']]  \n,Automatic,\n      01/2021
# freq                  1378             1371            36633         2883
#
#              fuel_type       power  ... emissions_sticker  \
# count            62766       62766  ...             62766
# unique              12         361  ...                 6
# top     \n,Gasoline,\n  [None, '']  ...        \n,None,\n
# freq             36942        5333  ...             62632
#
#                       \nComfort & Convenience\n  \
# count                                     62766
# unique                                    28445
# top     [['Air conditioning', 'Power windows']]
# freq                                        245
#
#                             \nEntertainment & Media\n  \
# count                                           62766
# unique                                           1871
# top     [['CD player', 'On-board computer', 'Radio']]
# freq                                             7605
#
#                                     \nSafety & Security\n  \
# count                                               62766
# unique                                              19501
# top     [['ABS', 'Alarm system', 'Central door lock', ...
# freq                                                  470
#
#                           extras   \ncolour \nmanufacturer_color  \
# count                      62766      62766                62766
# unique                      8457         15                    1
# top     [['Alloy wheels (16")']]  \n4, Grey                 None
# freq                        2147      20667                62766
#
#                   \npaint   upholstery_colour   upholstery
# count               62766                62766        62766
# unique                  2                   12            7
# top     \npaint, Metallic  \nupholstery, Black   \n8, Cloth
# freq                44423                30365        23375
#
# [4 rows x 48 columns]

# %%
df.describe().T
# Out:
#                            count unique  \
# location                   62766   2344
# make                       62766     20
# model                      62766    754
# short_description          62617  54368
# price                      62766   8179
# mileage                    62766  45618
# gearbox                    62766     10
# registration               62729    302
# fuel_type                  62766     12
# power                      62766    361
# seller                     62766      5
# body_type                  62766     13
# type                       62766      5
# drivetrain                 62766      4
# seats                      62766     11
# doors                      62766      7
# country_version            62766     27
# offer_number               62766  50143
# warranty                   62766     17
# Mileage                    62766      2
# first_registration         62766    298
# production_date            62766     26
# general_inspection         62766     94
# last_service               62766      1
# full_service_history       62766      2
# non_smoker_vehicle         62766      2
# previous_owner             62766     12
# last_timing_belt_change    62766     82
# Power                      62766    357
# Gearbox                    62766      4
# engine_size                62766    446
# gears                      62766     10
# cylinders                  62766     11
# empty_weight               62766   1539
# Fuel_type                  62766     21
# fuel_consumption           62766   3761
# co2_emissions              62766    346
# emission_class             62766     11
# emissions_sticker          62766      6
# \nComfort & Convenience\n  62766  28445
# \nEntertainment & Media\n  62766   1871
# \nSafety & Security\n      62766  19501
# extras                     62766   8457
# \ncolour                   62766     15
# \nmanufacturer_color       62766      1
# \npaint                    62766      2
#  upholstery_colour         62766     12
#  upholstery                62766      7
#
#                                                                          top  \
# location                                                       ROTTERDAM, NL
# make                                                              \n,BMW ,\n
# model                                                               \n,A3,\n
# short_description                                           1.4 TSI Highline
# price                                                     [['\n', '', '\n']]
# mileage                                                      ['', ['10 km']]
# gearbox                                                      \n,Automatic,\n
# registration                                                         01/2021
# fuel_type                                                     \n,Gasoline,\n
# power                                                             [None, '']
# seller                                                  ['\n', ['Dealer\n']]
# body_type                                             \n,Off-Road/Pick-up,\n
# type                                                              \n,Used,\n
# drivetrain                                                       \n,Front,\n
# seats                                                                    \n5
# doors                                                                    \n5
# country_version                                         Country version,None
# offer_number                                                          None\n
# warranty                                                          \n,None,\n
# Mileage                                                       [['\n'], ['']]
# first_registration                                                   01/2021
# production_date                                                         None
# general_inspection                                                       New
# last_service                                                            None
# full_service_history                                               \n,Yes,\n
# non_smoker_vehicle                                                \n,None,\n
# previous_owner                                            [['\n'], ['None']]
# last_timing_belt_change                                   [['\n'], ['None']]
# Power                                                             \n,None,\n
# Gearbox                                                      \n,Automatic,\n
# engine_size                                                       \n,None,\n
# gears                                                                \n,6,\n
# cylinders                                                            \n,4,\n
# empty_weight                                                  \n,1,295 kg,\n
# Fuel_type                                                     \n,Gasoline,\n
# fuel_consumption                                                  \n,None,\n
# co2_emissions                                                     \n,None,\n
# emission_class                                                  \n,Euro 6,\n
# emissions_sticker                                                 \n,None,\n
# \nComfort & Convenience\n            [['Air conditioning', 'Power windows']]
# \nEntertainment & Media\n      [['CD player', 'On-board computer', 'Radio']]
# \nSafety & Security\n      [['ABS', 'Alarm system', 'Central door lock', ...
# extras                                              [['Alloy wheels (16")']]
# \ncolour                                                           \n4, Grey
# \nmanufacturer_color                                                    None
# \npaint                                                    \npaint, Metallic
#  upholstery_colour                                       \nupholstery, Black
#  upholstery                                                       \n8, Cloth
#
#                             freq
# location                    1379
# make                        6942
# model                       1171
# short_description             58
# price                       1378
# mileage                     1371
# gearbox                    36633
# registration                2883
# fuel_type                  36942
# power                       5333
# seller                     57428
# body_type                  17348
# type                       55523
# drivetrain                 33522
# seats                      46671
# doors                      45496
# country_version            54824
# offer_number                9928
# warranty                   41605
# Mileage                    62633
# first_registration          2883
# production_date            56210
# general_inspection         15532
# last_service               62766
# full_service_history       43101
# non_smoker_vehicle         57769
# previous_owner             58373
# last_timing_belt_change    61925
# Power                       5330
# Gearbox                    36638
# engine_size                 5143
# gears                      18882
# cylinders                  41993
# empty_weight                1529
# Fuel_type                  22959
# fuel_consumption           11767
# co2_emissions               9867
# emission_class             19704
# emissions_sticker          62632
# \nComfort & Convenience\n    245
# \nEntertainment & Media\n   7605
# \nSafety & Security\n        470
# extras                      2147
# \ncolour                   20667
# \nmanufacturer_color       62766
# \npaint                    44423
#  upholstery_colour         30365
#  upholstery                23375

# %%
df.head()
# Out:
#             location         make     model  \
# 0   LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power  ... emissions_sticker  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ...        \n,None,\n
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ...        \n,None,\n
# 2      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ...        \n,None,\n
# 3      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ...        \n,None,\n
# 4      10/2017  \n,Gasoline,\n  110 kW (150 hp),  ...        \n,None,\n
#
#                            \nComfort & Convenience\n  \
# 0  [['Air conditioning', 'Armrest', 'Automatic cl...
# 1  [['Air conditioning', 'Automatic climate contr...
# 2  [['Air conditioning', 'Armrest', 'Automatic cl...
# 3  [['Air conditioning', 'Armrest', 'Automatic cl...
# 4  [['Air conditioning', 'Armrest', 'Electrical s...
#
#                            \nEntertainment & Media\n  \
# 0                           [['CD player', 'Radio']]
# 1                           [['CD player', 'Radio']]
# 2  [['Bluetooth', 'CD player', 'On-board computer...
# 3  [['CD player', 'MP3', 'On-board computer', 'Ra...
# 4      [['CD player', 'On-board computer', 'Radio']]
#
#                                \nSafety & Security\n  \
# 0  [['ABS', 'Alarm system', 'Central door lock', ...
# 1  [['Alarm system', 'Central door lock', 'Centra...
# 2  [['ABS', 'Central door lock with remote contro...
# 3  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
# 4  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
#
#                                               extras    \ncolour  \
# 0                                 [['Alloy wheels']]   \n4, Grey
# 1                           [['Alloy wheels (16")']]  \n4, White
# 2                           [['Alloy wheels (15")']]   \n4, Grey
# 3  [['Alloy wheels (17")', 'Shift paddles', 'Spor...  \n4, Black
# 4  [['Alloy wheels (17")', 'Sport seats', 'Sport ...   \n4, Grey
#
#   \nmanufacturer_color            \npaint   upholstery_colour   \
# 0                 None  \npaint, Metallic  \nupholstery, Black
# 1                 None               None  \nupholstery, Black
# 2                 None  \npaint, Metallic                 None
# 3                 None               None  \nupholstery, Black
# 4                 None  \npaint, Metallic  \nupholstery, Black
#
#          upholstery
# 0         \n8, Cloth
# 1         \n8, Cloth
# 2               None
# 3  \n8, Part leather
# 4         \n8, Cloth
#
# [5 rows x 48 columns]

# %%
df.dtypes
# Out:
# location                     object
# make                         object
# model                        object
# short_description            object
# price                        object
# mileage                      object
# gearbox                      object
# registration                 object
# fuel_type                    object
# power                        object
# seller                       object
# body_type                    object
# type                         object
# drivetrain                   object
# seats                        object
# doors                        object
# country_version              object
# offer_number                 object
# warranty                     object
# Mileage                      object
# first_registration           object
# production_date              object
# general_inspection           object
# last_service                 object
# full_service_history         object
# non_smoker_vehicle           object
# previous_owner               object
# last_timing_belt_change      object
# Power                        object
# Gearbox                      object
# engine_size                  object
# gears                        object
# cylinders                    object
# empty_weight                 object
# Fuel_type                    object
# fuel_consumption             object
# co2_emissions                object
# emission_class               object
# emissions_sticker            object
# \nComfort & Convenience\n    object
# \nEntertainment & Media\n    object
# \nSafety & Security\n        object
# extras                       object
# \ncolour                     object
# \nmanufacturer_color         object
# \npaint                      object
#  upholstery_colour           object
#  upholstery                  object
# dtype: object

# %%
#df13 = df.iloc[0:13]

# %%
df13=df.T.iloc[0:13]

# %%
df13.shape
# Out:
# (13, 62766)

# %%
df13.head()
# Out:
#                                          0      \
# location                      LOON OP ZAND, NL
# make                               \n,Audi ,\n
# model                                 \n,A3,\n
# short_description    2.0 FSI Ambition Pro Line
# price              [['\n', '€ 4,450.-', '\n']]
#
#                                                                1      \
# location                                                 HEERLEN, NL
# make                                                     \n,Audi ,\n
# model                                                       \n,A3,\n
# short_description  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# price                                   [['\n', '€ 12,950.-', '\n']]
#
#                                                              2      \
# location                                         BAARLE-NASSAU, NL
# make                                                   \n,Audi ,\n
# model                                                     \n,A1,\n
# short_description  1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# price                                 [['\n', '€ 12,450.-', '\n']]
#
#                                                                3      \
# location                                                 ZUTPHEN, NL
# make                                                     \n,Audi ,\n
# model                                                       \n,A1,\n
# short_description  S-Line | Automaat | Navigatie | Cruise-/Climat...
# price                                   [['\n', '€ 14,945.-', '\n']]
#
#                                                                4      \
# location                                             HAAKSBERGEN, NL
# make                                                     \n,Audi ,\n
# model                                                       \n,A3,\n
# short_description  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
# price                                   [['\n', '€ 24,900.-', '\n']]
#
#                                           5      \
# location                              WEZEP, NL
# make                                \n,Audi ,\n
# model                                  \n,A3,\n
# short_description    Sportback 30 TFSI/Automaat
# price              [['\n', '€ 24,750.-', '\n']]
#
#                                                                6      \
# location                                                 UTRECHT, NL
# make                                                     \n,Audi ,\n
# model                                                       \n,A1,\n
# short_description  Sportback 1.4 TFSI Pro Line S | S Line Pack | ...
# price                                   [['\n', '€ 15,945.-', '\n']]
#
#                                                         7      \
# location                                           HEESCH, NL
# make                                              \n,Audi ,\n
# model                                                \n,A3,\n
# short_description  1.8 TFSI Ambition Pro Line S aut. S-tronic
# price                            [['\n', '€ 12,950.-', '\n']]
#
#                                                                8      \
# location                                  VALKENBURG AAN DE GEUL, NL
# make                                                     \n,Audi ,\n
# model                                                       \n,A1,\n
# short_description  1.4 TSI  S-Tronic Navigatie MF Stuurwiel LED V...
# price                                   [['\n', '€ 13,950.-', '\n']]
#
#                                                                9      ...  \
# location                                             NIJKERK GLD, NL  ...
# make                                                     \n,Audi ,\n  ...
# model                                                       \n,A3,\n  ...
# short_description  Sportback 1.2 TFSI Ambition Stoelverw.V+A Airc...  ...
# price                                   [['\n', '€ 10,945.-', '\n']]  ...
#
#                                                                62756  \
# location                                                LELYSTAD, NL
# make                                                    \n,Volvo ,\n
# model                                                      \n,S80,\n
# short_description  2.5 T Summum LPG / AUTOMAAT /VOL LEDER NAVI VE...
# price                                    [['\n', '€ 5,999.-', '\n']]
#
#                                          62757  \
# location                         Amsterdam, NL
# make                              \n,Volvo ,\n
# model                                \n,S80,\n
# short_description          2.4 Elan 170 PK LPG
# price              [['\n', '€ 2,250.-', '\n']]
#
#                                                         62758  \
# location                                          DRONTEN, NL
# make                                             \n,Volvo ,\n
# model                                               \n,S80,\n
# short_description  2.4 Summum Graphite schuifdak / Navi / LPG
# price                             [['\n', '€ 3,500.-', '\n']]
#
#                                                      62759  \
# location                                  WENUM WIESEL, NL
# make                                          \n,Volvo ,\n
# model                                            \n,S60,\n
# short_description  2.4 Momentum AUTOMAAT YOUNGTIMER LPG G3
# price                          [['\n', '€ 8,950.-', '\n']]
#
#                                                                62760  \
# location                                                 KLIMMEN, NL
# make                                                    \n,Volvo ,\n
# model                                                      \n,S40,\n
# short_description  2.0F 145pk Business Edition * Leer * Navi * Xenon
# price                                    [['\n', '€ 9,250.-', '\n']]
#
#                                          62761  \
# location                        Etten-Leur, NL
# make                              \n,Volvo ,\n
# model                                \n,S60,\n
# short_description    2.4 Edition APK/LMV/Airco
# price              [['\n', '€ 1,799.-', '\n']]
#
#                                                          62762  \
# location                               HENDRIK-IDO-AMBACHT, NL
# make                                              \n,Volvo ,\n
# model                                                \n,S60,\n
# short_description  2.4 Kinetic LPG-G3 NAP/LEER/NAVI/DAK/NW APK
# price                              [['\n', '€ 1,999.-', '\n']]
#
#                                                                62763  \
# location                                                LELYSTAD, NL
# make                                                    \n,Volvo ,\n
# model                                                      \n,S60,\n
# short_description  2.0T Edition,1e Eigenaar,LPG G3,Onderbouw,Navi...
# price                                    [['\n', '€ 3,449.-', '\n']]
#
#                                          62764  \
# location                         Amsterdam, NL
# make                              \n,Volvo ,\n
# model                                \n,S40,\n
# short_description                          2.4
# price              [['\n', '€ 1,650.-', '\n']]
#
#                                                            62765
# location                                         SOESTERBERG, NL
# make                                                \n,Volvo ,\n
# model                                                  \n,S60,\n
# short_description  2.4 Airco, Cruise Control, Stuurbekrachtiging
# price                                  [['\n', '€ 944.-', '\n']]
#
# [5 rows x 62766 columns]

# %%
df13=df13.T

# %%
df13.head()
# Out:
#             location         make     model  \
# 0   LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power                seller  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 2      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 3      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 4      10/2017  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
#
#        body_type        type
# 0  \n,Compact,\n  \n,Used,\n
# 1  \n,Compact,\n  \n,Used,\n
# 2  \n,Compact,\n  \n,Used,\n
# 3  \n,Compact,\n  \n,Used,\n
# 4  \n,Compact,\n  \n,Used,\n

# %%
df13.shape
# Out:
# (62766, 13)

# %%
df14 = df3.iloc[:, 1:14]

# %%
df14.shape
# Out:
# (62766, 13)

# %%
df14.head()
# Out:
#             location         make     model  \
# 0   LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power                seller  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 2      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 3      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 4      10/2017  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
#
#        body_type        type
# 0  \n,Compact,\n  \n,Used,\n
# 1  \n,Compact,\n  \n,Used,\n
# 2  \n,Compact,\n  \n,Used,\n
# 3  \n,Compact,\n  \n,Used,\n
# 4  \n,Compact,\n  \n,Used,\n

# %%
df14["make"].head()
# Out:
# 0    \n,Audi ,\n
# 1    \n,Audi ,\n
# 2    \n,Audi ,\n
# 3    \n,Audi ,\n
# 4    \n,Audi ,\n
# Name: make, dtype: object

# %%
df14["make"]=df14["make"].replace("\n,","",regex=True)

# %%
df14.head()
# Out:
#             location      make     model  \
# 0   LOON OP ZAND, NL  Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power                seller  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 2      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 3      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 4      10/2017  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
#
#        body_type        type
# 0  \n,Compact,\n  \n,Used,\n
# 1  \n,Compact,\n  \n,Used,\n
# 2  \n,Compact,\n  \n,Used,\n
# 3  \n,Compact,\n  \n,Used,\n
# 4  \n,Compact,\n  \n,Used,\n

# %%
df14["make"].value_counts()   # which value , how many times exist
# Out:
# BMW ,\n              6942
# Volkswagen ,\n       6436
# Mercedes-Benz ,\n    5860
# Audi ,\n             5675
# Volvo ,\n            4734
# Renault ,\n          4255
# Ford ,\n             4036
# Peugeot ,\n          3492
# Toyota ,\n           2783
# Skoda ,\n            2588
# Kia ,\n              2502
# Opel ,\n             2342
# Hyundai ,\n          2271
# Mazda ,\n            2161
# Citroen ,\n          2146
# Fiat ,\n             1923
# Honda ,\n             948
# Dacia ,\n             829
# Chevrolet ,\n         427
# Tesla ,\n             416
# Name: make, dtype: int64

# %%
df14["gearbox"].value_counts()   # which value , how many times exist
# Out:
# \n,Automatic,\n         36633
# \n,Manual,\n            25430
# \n,Semi-automatic,\n      611
# ['\n', None, '\n']         85
# \n,02/2022,\n               2
# \n,02/2020,\n               1
# \n,08/2021,\n               1
# \n,03/2014,\n               1
# \n,09/2021,\n               1
# \n,07/2017,\n               1
# Name: gearbox, dtype: int64

# %%
#df14["make"].str.split(",").str[1]
df14["make"]=df14["make"].str.split(",").str[0]
df14["make"].head()
# Out:
# 0    Audi
# 1    Audi
# 2    Audi
# 3    Audi
# 4    Audi
# Name: make, dtype: object

# %%
df14['make'].unique()
# Out:
# array(['Audi ', 'BMW ', 'Ford ', 'Mercedes-Benz ', 'Opel ', 'Volkswagen ',
#        'Renault ', 'Citroen ', 'Chevrolet ', 'Dacia ', 'Fiat ', 'Honda ',
#        'Hyundai ', 'Kia ', 'Mazda ', 'Peugeot ', 'Skoda ', 'Toyota ',
#        'Tesla ', 'Volvo '], dtype=object)

# %%
df14["make"].value_counts()   # which value , how many times exist

# %%
#df14["make"]=df14["make"].replace("\n,","",regex=True)
df14["gearbox"]=df14["gearbox"].str.split(",").str[1]
df14["gearbox"].head()
# Out:
# 0    Automatic
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic
# Name: gearbox, dtype: object

# %%
df14["gearbox"].value_counts()   # which value , how many times exist
# Out:
# Automatic         36633
# Manual            25430
# Semi-automatic      611
#  None                85
# 02/2022               2
# 02/2020               1
# 08/2021               1
# 03/2014               1
# 09/2021               1
# 07/2017               1
# Name: gearbox, dtype: int64

# %%
df14["model"].value_counts()   # which value , how many times exist
# Out:
# \n,A3,\n                  1171
# \n,Megane,\n               932
# \n,Golf,\n                 921
# \n,A4,\n                   843
# \n,Focus,\n                836
#                           ...
# \n,MX-3,\n                   1
# \n,Z3 M,\n                   1
# \n,SLK 300,\n                1
# \n,Fox,\n                    1
# \n,Active Hybrid X6,\n       1
# Name: model, Length: 754, dtype: int64

# %%
df14['model'].unique()

# %%
df14["model"]=df14["model"].str.split(",").str[1]
df14["model"].head()
# Out:
# 0    A3
# 1    A3
# 2    A1
# 3    A1
# 4    A3
# Name: model, dtype: object

# %%
df14["fuel_type"].value_counts()   # which value , how many times exist
# Out:
# \n,Gasoline,\n             36942
# \n,Diesel,\n               11754
# \n,Electric/Gasoline,\n     8179
# \n,Electric,\n              4906
# \n,LPG,\n                    547
# \n,Electric/Diesel,\n        254
# \n,CNG,\n                     98
# \n,Hydrogen,\n                62
# \n,Ethanol,\n                  9
# \n,Others,\n                   7
# \n,Automatic,\n                5
# \n,Manual,\n                   3
# Name: fuel_type, dtype: int64

# %%
df14["fuel_type"]=df14["fuel_type"].str.split(",").str[1]
df14["fuel_type"].head()
# Out:
# 0    Gasoline
# 1    Gasoline
# 2    Gasoline
# 3    Gasoline
# 4    Gasoline
# Name: fuel_type, dtype: object

# %%
df14['power'].value_counts()
# Out:
# [None, '']          5333
# 110 kW (150 hp),    3677
# 88 kW (120 hp),     2518
# 100 kW (136 hp),    2190
# 90 kW (122 hp),     2174
#                     ...
# 378 kW (514 hp),       1
# 282 kW (383 hp),       1
# 470 kW (639 hp),       1
# 451 kW (613 hp),       1
# 10 kW (14 hp),         1
# Name: power, Length: 361, dtype: int64

# %%
u = df14['power'].unique()
for i in u:
  print(i)

# %%
df14['body_type'].value_counts()
# Out:
# \n,Off-Road/Pick-up,\n    17348
# \n,Compact,\n             13185
# \n,Station wagon,\n       11318
# \n,Van,\n                  6243
# \n,Sedan,\n                5341
# \n,Convertible,\n          3645
# \n,Transporter,\n          2249
# \n,Coupe,\n                1923
# \n,None,\n                  948
# \n,Other,\n                 562
# \n,Panel van,\n               2
# \n,Car transport,\n           1
# \n,Flatbed van,\n             1
# Name: body_type, dtype: int64

# %%
df14["body_type"]=df14["body_type"].str.split(",").str[1]
df14["body_type"].head()
# Out:
# 0    Compact
# 1    Compact
# 2    Compact
# 3    Compact
# 4    Compact
# Name: body_type, dtype: object

# %%
df14['type'].value_counts()
# Out:
# \n,Used,\n              55523
# \n,New,\n                3413
# \n,Demonstration,\n      1889
# \n,Pre-registered,\n      993
# \n,None,\n                948
# Name: type, dtype: int64

# %%
df14["type"]=df14["type"].str.split(",").str[1]
df14["type"].head()
# Out:
# 0    Used
# 1    Used
# 2    Used
# 3    Used
# 4    Used
# Name: type, dtype: object

# %%
df14.head()
# Out:
#             location   make model  \
# 0   LOON OP ZAND, NL  Audi     A3
# 1        HEERLEN, NL  Audi     A3
# 2  BAARLE-NASSAU, NL  Audi     A1
# 3        ZUTPHEN, NL  Audi     A1
# 4    HAAKSBERGEN, NL  Audi     A3
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage    gearbox registration  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  Automatic      08/2003
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  Automatic      10/2013
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  Automatic      06/2015
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  Automatic      10/2015
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  Automatic      10/2017
#
#   fuel_type             power                seller body_type  type
# 0  Gasoline  110 kW (150 hp),  ['\n', ['Dealer\n']]   Compact  Used
# 1  Gasoline   92 kW (125 hp),  ['\n', ['Dealer\n']]   Compact  Used
# 2  Gasoline   92 kW (125 hp),  ['\n', ['Dealer\n']]   Compact  Used
# 3  Gasoline   92 kW (125 hp),  ['\n', ['Dealer\n']]   Compact  Used
# 4  Gasoline  110 kW (150 hp),  ['\n', ['Dealer\n']]   Compact  Used

# %%
df15 = df3.iloc[:, 1:14]

# %%
df15.head()
# Out:
#             location         make     model  \
# 0   LOON OP ZAND, NL  \n,Audi ,\n  \n,A3,\n
# 1        HEERLEN, NL  \n,Audi ,\n  \n,A3,\n
# 2  BAARLE-NASSAU, NL  \n,Audi ,\n  \n,A1,\n
# 3        ZUTPHEN, NL  \n,Audi ,\n  \n,A1,\n
# 4    HAAKSBERGEN, NL  \n,Audi ,\n  \n,A3,\n
#
#                                    short_description  \
# 0                          2.0 FSI Ambition Pro Line
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 3  S-Line | Automaat | Navigatie | Cruise-/Climat...
# 4  Sportback 1.5 TFSI Sport | Dealer Onderhouden ...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 3  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
# 4  [['\n', '€ 24,900.-', '\n']]   ['', ['55,815 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power                seller  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 2      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 3      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 4      10/2017  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
#
#        body_type        type
# 0  \n,Compact,\n  \n,Used,\n
# 1  \n,Compact,\n  \n,Used,\n
# 2  \n,Compact,\n  \n,Used,\n
# 3  \n,Compact,\n  \n,Used,\n
# 4  \n,Compact,\n  \n,Used,\n

# %%
df15['type'].value_counts()
# Out:
# \n,Used,\n              55523
# \n,New,\n                3413
# \n,Demonstration,\n      1889
# \n,Pre-registered,\n      993
# \n,None,\n                948
# Name: type, dtype: int64

# %%
type(df14['make'])
# Out:
# pandas.core.series.Series

# %%
df14['make'].describe()
# Out:
# count     62766
# unique       20
# top        BMW
# freq       6942
# Name: make, dtype: object

# %%
df14['model'].describe()
# Out:
# count     62766
# unique      754
# top          A3
# freq       1171
# Name: model, dtype: object

# %%
df14['make'].unique()             # ?
# Out:
# array(['Audi ', 'BMW ', 'Ford ', 'Mercedes-Benz ', 'Opel ', 'Volkswagen ',
#        'Renault ', 'Citroen ', 'Chevrolet ', 'Dacia ', 'Fiat ', 'Honda ',
#        'Hyundai ', 'Kia ', 'Mazda ', 'Peugeot ', 'Skoda ', 'Toyota ',
#        'Tesla ', 'Volvo '], dtype=object)

# %%
df14["make"].isnull().sum()
# Out:
# 0
